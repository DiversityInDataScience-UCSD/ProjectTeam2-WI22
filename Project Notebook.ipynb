# %%
import pandas as pd

# %%
data = pd.read_csv('data/FCS_2016_ICPSR/ICPSR_36962/DS0001/36962-0001-Data.tsv', delimiter='\t')
data
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (46,163,164,337,342,419,420,445,446,447,486) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        USSCIDN ABUSHI ACCAP ACCCAT ACCGDLN ACCOFFLV ACCTRESP ADJL_BHI  \
# 0      2282001      0     0              1                -3        A
# 1      2282067      0     0              1                -2        A
# 2      2282068      0     0              1                -2        A
# 3      2282102      0     0              1                -3      A21
# 4      2282108      0     0              1                 0        A
# ...        ...    ...   ...    ...     ...      ...      ...      ...
# 67737  2374291      0     0              2                -3        E
# 67738  2374397      0     0              1                -3        A
# ...

# %%
list1 = [46,163,164,337,342,419,420,445,446,447,486]
counter = 0
for i in data.columns:
    if counter in list1:
        print(i)
    counter += 1
# Out:
# AGE
# DOBMON
# DOBYR
# POOFFICE
# PROBDUM
# SENSPLT0
# SENTIMP
# TIMSERVC
# TIMSERVM
# TIMSERVD
# YEARS
